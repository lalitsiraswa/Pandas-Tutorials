# %%
import numpy as np
import pandas as pd

# %%
A = [1, 2, 3, 4]
B = [5, 6, 7, 8]
C = [9, 0, 1, 2]
D = [3, 4, 5, 6]
E = [7, 8, 9, 0]

# %%
df = pd.DataFrame([A, B, C, D, E], ["A", "B", "C", "D", "E"], ["a", "b", "c", "d"])
df
# Out:
#    a  b  c  d
# A  1  2  3  4
# B  5  6  7  8
# C  9  0  1  2
# D  3  4  5  6
# E  7  8  9  0

# %%
df["e"] = [1, 2, 3, 4, 5]
df
# Out:
#    a  b  c  d  e
# A  1  2  3  4  1
# B  5  6  7  8  2
# C  9  0  1  2  3
# D  3  4  5  6  4
# E  7  8  9  0  5

# %%
df["f"] = df["d"] + df["e"]
df
# Out:
#    a  b  c  d  e   f
# A  1  2  3  4  1   5
# B  5  6  7  8  2  10
# C  9  0  1  2  3   5
# D  3  4  5  6  4  10
# E  7  8  9  0  5   5

# %%
df["a"]
# Out:
# A    1
# B    5
# C    9
# D    3
# E    7
# Name: a, dtype: int64

# %%
df.drop(index="E", columns=["f", "e"])
# Out:
#    a  b  c  d
# A  1  2  3  4
# B  5  6  7  8
# C  9  0  1  2
# D  3  4  5  6

# %%
df
# Out:
#    a  b  c  d  e   f
# A  1  2  3  4  1   5
# B  5  6  7  8  2  10
# C  9  0  1  2  3   5
# D  3  4  5  6  4  10
# E  7  8  9  0  5   5

# %%
df.drop("C")
# Out:
#    a  b  c  d  e   f
# A  1  2  3  4  1   5
# B  5  6  7  8  2  10
# D  3  4  5  6  4  10
# E  7  8  9  0  5   5

# %%
df
# Out:
#    a  b  c  d  e   f
# A  1  2  3  4  1   5
# B  5  6  7  8  2  10
# C  9  0  1  2  3   5
# D  3  4  5  6  4  10
# E  7  8  9  0  5   5

# %%
df.drop(columns="f")
# Out:
#    a  b  c  d  e
# A  1  2  3  4  1
# B  5  6  7  8  2
# C  9  0  1  2  3
# D  3  4  5  6  4
# E  7  8  9  0  5

# %%
df
# Out:
#    a  b  c  d  e   f
# A  1  2  3  4  1   5
# B  5  6  7  8  2  10
# C  9  0  1  2  3   5
# D  3  4  5  6  4  10
# E  7  8  9  0  5   5

# %%
df.drop(index="E", columns="f", inplace=True)
df
# Out:
#    a  b  c  d  e
# A  1  2  3  4  1
# B  5  6  7  8  2
# C  9  0  1  2  3
# D  3  4  5  6  4

# %%
A = [1, 2, 3, 4]
B = [5, 6, 7, 8]
C = [9, 0, 1, 2]
D = [3, 4, 5, 6]
E = [7, 8, 9, 0]

df = pd.DataFrame([A, B, C, D, E], ["A", "B", "C", "D", "E"], ['a', 'b', 'c', 'd'])
df
# Out:
#    a  b  c  d
# A  1  2  3  4
# B  5  6  7  8
# C  9  0  1  2
# D  3  4  5  6
# E  7  8  9  0

# %%
df["f"] = df["a"] + df["b"]
df["g"] = df["c"] + df["d"]
df["h"] = df["f"] + df["g"]
df
# Out:
#    a  b  c  d   f   g   h
# A  1  2  3  4   3   7  10
# B  5  6  7  8  11  15  26
# C  9  0  1  2   9   3  12
# D  3  4  5  6   7  11  18
# E  7  8  9  0  15   9  24

# %%
print(df.drop("E", axis = 0, inplace = False))
print(df.drop("h", axis = 1, inplace = False))
# Out:
#    a  b  c  d   f   g   h
# A  1  2  3  4   3   7  10
# B  5  6  7  8  11  15  26
# C  9  0  1  2   9   3  12
# D  3  4  5  6   7  11  18
#    a  b  c  d   f   g
# A  1  2  3  4   3   7
# B  5  6  7  8  11  15
# C  9  0  1  2   9   3
# D  3  4  5  6   7  11
# E  7  8  9  0  15   9

# %%
df
# Out:
#    a  b  c  d   f   g   h
# A  1  2  3  4   3   7  10
# B  5  6  7  8  11  15  26
# C  9  0  1  2   9   3  12
# D  3  4  5  6   7  11  18
# E  7  8  9  0  15   9  24

# %%
df.drop(columns=["a", "b"])
# Out:
#    c  d   f   g   h
# A  3  4   3   7  10
# B  7  8  11  15  26
# C  1  2   9   3  12
# D  5  6   7  11  18
# E  9  0  15   9  24

# %%
df.drop(["A", "B"])
# Out:
#    a  b  c  d   f   g   h
# C  9  0  1  2   9   3  12
# D  3  4  5  6   7  11  18
# E  7  8  9  0  15   9  24

# %%
df
# Out:
#    a  b  c  d   f   g   h
# A  1  2  3  4   3   7  10
# B  5  6  7  8  11  15  26
# C  9  0  1  2   9   3  12
# D  3  4  5  6   7  11  18
# E  7  8  9  0  15   9  24
