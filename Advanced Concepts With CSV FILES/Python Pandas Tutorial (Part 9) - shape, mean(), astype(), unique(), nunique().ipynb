# %%
import pandas as pd
import numpy as np

# %%
na_vals = ["NA", "MISSING"]
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent", na_values = na_vals)
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 60)
df.head(4)
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NaN         13  Monthly
# 2           I am a developer by profession       No   NaN         19      NaN
# 3              I code primarily as a hobby      Yes   NaN         15      NaN
# 4           I am a developer by profession      Yes  25.0         18      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
# 4                 NaN            NaN             Albania    Albanian lek
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
# ...

# %%
df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
Developer_respodents = df.shape[0]

# %%
df["YearsCode"].head(5)
# Out:
# Respondent
# 1    36
# 2     7
# 3     4
# 4     7
# 5    15
# Name: YearsCode, dtype: object

# %%
type(df["YearsCode"])
# Out:
# pandas.core.series.Series

# %%
Year_Experience = df["YearsCode"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna)
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df["YearsCode"] = df["YearsCode"].astype(dtype = float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-012b0b166872> in <module>
# ----> 1 df["YearsCode"] = df["YearsCode"].astype(dtype = float)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
type(np.nan)
# Out:
# float

# %%
df["YearsCode"].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df["YearsCode"].nunique()
# Out:
# 52

# %%
len(df["YearsCode"].unique())
# Out:
# 53

# %%
df["YearsCode"].value_counts().head(5)
# Out:
# 10    4510
# 5     4249
# 6     3834
# 7     3477
# 8     3407
# Name: YearsCode, dtype: int64

# %%
len(df["YearsCode"].value_counts())
# Out:
# 52

# %%
len(df["YearsCode"].value_counts().index)
# Out:
# 52

# %%
df["YearsCode"].value_counts().index
# Out:
# Index(['10', '5', '6', '7', '8', '4', '3', '15', '20', '12', '9', '2', '11',
#        '14', '13', '25', '16', '30', '18', '17', '1', '22', 'Less than 1 year',
#        '19', '35', '23', '21', '40', '24', '26', '27', '28', '32', '38', '37',
#        '36', '33', '34', '29', '39', '31', 'More than 50 years', '42', '45',
#        '41', '43', '44', '46', '50', '48', '47', '49'],
#       dtype='object')

# %%
df["YearsCode"].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df["YearsCode"].replace(to_replace = "Less than 1 year", value = 0, inplace = True)

# %%
df["YearsCode"].replace(to_replace = "More than 50 years", value = 51, inplace = True)

# %%
df["YearsCode"].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df["YearsCode"] = df["YearsCode"].astype(dtype = float)

# %%
df["YearsCode"].unique()
# Out:
# array([36.,  7.,  4., 15.,  6., 17.,  8., 10., 35.,  5., 37., 19.,  9.,
#        22., 30., 23., 20.,  2.,  0.,  3., 13., 25., 16., 43., 11., 38.,
#        33., nan, 24., 21., 12., 40., 27., 50., 46., 14., 18., 28., 32.,
#        44., 26., 42., 31., 34., 29.,  1., 39., 41., 45., 51., 47., 49.,
#        48.])

# %%
df["YearsCode"].mean()
# Out:
# 12.709052770265584

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...
