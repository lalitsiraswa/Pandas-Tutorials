# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 60)
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df["ConvertedComp"].mean()
# Out:
# 103756.05014961446

# %%
df["ConvertedComp"].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df["ConvertedComp"].count()
# Out:
# 34756

# %%
df["ConvertedComp"].describe()
# Out:
# count    3.475600e+04
# mean     1.037561e+05
# std      2.268853e+05
# min      0.000000e+00
# 25%      2.464800e+04
# 50%      5.404900e+04
# 75%      9.500000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df["ConvertedComp"].median()
# Out:
# 54049.0

# %%
df["ConvertedComp"].count()
# Out:
# 34756

# %%
print(df.index.max(), "\n")
print(df.index.min(), "\n")
# Out:
# 65639
#
# 1

# %%
df["ConvertedComp"].value_counts().head(5)
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 2000000.0    258
# 1000000.0    258
# Name: ConvertedComp, dtype: int64

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
filt = df["LanguageWorkedWith"].str.contains("Python", na = False)
df.loc[filt, "LanguageWorkedWith"].head(5)
# Out:
# Respondent
# 3                             Objective-C;Python;Swift
# 8                                           Python;SQL
# 10                 HTML/CSS;Java;JavaScript;Python;SQL
# 13                                 C;JavaScript;Python
# 15    Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# Name: LanguageWorkedWith, dtype: object

# %%
df["LanguageWorkedWith"].value_counts().head(5)
# Out:
# HTML/CSS;JavaScript;PHP;SQL              1073
# HTML/CSS;JavaScript                       900
# C#;HTML/CSS;JavaScript;SQL                856
# C#;HTML/CSS;JavaScript;SQL;TypeScript     754
# HTML/CSS;JavaScript;TypeScript            697
# Name: LanguageWorkedWith, dtype: int64

# %%
schema_df.head(5)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
schema_df.loc["LanguageWorkedWith"]["QuestionText"]
# Out:
# 'Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
df["LanguageWorkedWith"].str.contains("Python").value_counts()
# Out:
# False    32091
# True     25287
# Name: LanguageWorkedWith, dtype: int64

# %%
df["LanguageWorkedWith"].value_counts().head(5)
# Out:
# HTML/CSS;JavaScript;PHP;SQL              1073
# HTML/CSS;JavaScript                       900
# C#;HTML/CSS;JavaScript;SQL                856
# C#;HTML/CSS;JavaScript;SQL;TypeScript     754
# HTML/CSS;JavaScript;TypeScript            697
# Name: LanguageWorkedWith, dtype: int64

# %%
df["LanguageWorkedWith"].value_counts(normalize = True).head(5)
# Out:
# HTML/CSS;JavaScript;PHP;SQL              0.018701
# HTML/CSS;JavaScript                      0.015685
# C#;HTML/CSS;JavaScript;SQL               0.014919
# C#;HTML/CSS;JavaScript;SQL;TypeScript    0.013141
# HTML/CSS;JavaScript;TypeScript           0.012148
# Name: LanguageWorkedWith, dtype: float64

# %%
df["OpSys"].head(5)
# Out:
# Respondent
# 1        Windows
# 2          MacOS
# 3    Linux-based
# 4    Linux-based
# 5        Windows
# Name: OpSys, dtype: object

# %%
df["OpSys"].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: OpSys, dtype: int64

# %%
df["OpSys"].value_counts(normalize = True)
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %%
df["OpSys"].count()
# Out:
# 56228

# %%
df["Country"].head(5)
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 3    Russian Federation
# 4               Albania
# 5         United States
# Name: Country, dtype: object

# %%
df["Country"].value_counts().head(5)
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# Name: Country, dtype: int64

# %%
schema_df.loc["Country"]["QuestionText"]
# Out:
# 'Where do you live?'

# %%
df.groupby(by = "Country")

# %%
country_grp = df.groupby(by = "Country")

# %%
country_grp.get_group("United States")
country_grp.get_group("India")
country_grp.get_group("Canada")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 26                             I am a developer by profession       No   NaN
# 32                             I am a developer by profession      Yes  31.0
# 51                             I am a developer by profession       No   NaN
# 66                             I am a developer by profession      Yes  21.0
# 75                             I am a developer by profession       No   NaN
# 78                                I code primarily as a hobby      Yes  27.0
# 79                             I am a developer by profession       No  28.0
# 88                     I am a student who is learning to code       No  21.0
# 94          I am not primarily a developer, but I write co...      Yes  21.0
# 95                             I am a developer by profession      Yes   NaN
# 97                             I am a developer by profession      Yes  30.0
# ...

# %%
filt = df["Country"] == "India"

# %%
# df[filt]
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 7                              I am a developer by profession      Yes   NaN
# 22                             I am a developer by profession      Yes   NaN
# 58                             I am a developer by profession      Yes   NaN
# 63                     I am a student who is learning to code      Yes  21.0
# 149                            I am a developer by profession      Yes  36.0
# 177                            I am a developer by profession      Yes   NaN
# 227                            I am a developer by profession      Yes  24.0
# 232                    I am a student who is learning to code       No  20.0
# 234                            I am a developer by profession      Yes  22.0
# 268                            I am a developer by profession      Yes   NaN
# 274                            I am a developer by profession      Yes  26.0
# ...

# %%
country_grp.get_group("United States")["LanguageWorkedWith"].value_counts().head(5)
# Out:
# C#;HTML/CSS;JavaScript;SQL               225
# C#;HTML/CSS;JavaScript;SQL;TypeScript    179
# HTML/CSS;JavaScript                      158
# HTML/CSS;JavaScript;PHP;SQL              122
# HTML/CSS;JavaScript;TypeScript           120
# Name: LanguageWorkedWith, dtype: int64

# %%
filt = (df["LanguageWorkedWith"].str.contains("Python")) & (df["Country"] == "India")

# %%
df.loc[filt, "LanguageWorkedWith"].value_counts().head(5)
# Out:
# Python                                           103
# C;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL     44
# HTML/CSS;JavaScript;Python;SQL                    42
# HTML/CSS;JavaScript;Python                        39
# C;C++;Python                                      31
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp["LanguageWorkedWith"].value_counts().loc["India"]
# Out:
# LanguageWorkedWith
# HTML/CSS;JavaScript;PHP;SQL                      180
# HTML/CSS;JavaScript                              149
# Java                                             149
# HTML/CSS;JavaScript;TypeScript                   121
# Python                                           103
# HTML/CSS;JavaScript;PHP                          101
# HTML/CSS;Java;JavaScript;SQL                      91
# C#;HTML/CSS;JavaScript;SQL                        86
# JavaScript                                        83
# Java;Kotlin                                       67
# C#;HTML/CSS;JavaScript;SQL;TypeScript             65
# Objective-C;Swift                                 63
# HTML/CSS;JavaScript;PHP;SQL;TypeScript            59
# HTML/CSS;Java;JavaScript                          52
# Java;SQL                                          50
# C;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL     44
# HTML/CSS;JavaScript;Python;SQL                    42
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
country_grp = df.groupby("Country")

# %%
print(type(country_grp), "\n")
# Out:
# <class 'pandas.core.groupby.groupby.DataFrameGroupBy'>

# %%
print(type(country_grp["Hobbyist"].value_counts()), "\n", "---------------------------------")
print(country_grp["Hobbyist"].value_counts()["India"], "\n")
print(country_grp["Hobbyist"].value_counts().loc["Australia"], "\n")
print(country_grp["Hobbyist"].value_counts().loc["United Kingdom"], "\n")
# Out:
# <class 'pandas.core.series.Series'>
#  ---------------------------------
# Hobbyist
# Yes    6645
# No     1758
# Name: Hobbyist, dtype: int64
#
# Hobbyist
# Yes    964
# No     244
# Name: Hobbyist, dtype: int64
#
# Hobbyist
# Yes    3029
# No      867
# Name: Hobbyist, dtype: int64

# %%
country_grp["Hobbyist"].value_counts()
# Out:
# Country                               Hobbyist
# Afghanistan                           Yes           64
#                                       No            20
# Albania                               Yes           44
#                                       No            10
# Algeria                               Yes           71
#                                       No            23
# Andorra                               Yes            9
#                                       No             4
# Angola                                Yes            5
#                                       No             4
# Antigua and Barbuda                   No             1
#                                       Yes            1
# Argentina                             Yes          301
#                                       No            94
# Armenia                               Yes           36
#                                       No            28
# ...

# %%
country_grp["Hobbyist"].value_counts().loc["Uruguay"]
# Out:
# Hobbyist
# Yes    71
# No     29
# Name: Hobbyist, dtype: int64

# %%
country_grp = df.groupby("Country")

# %%
country_grp["MainBranch"].value_counts()["India"]
# Out:
# MainBranch
# I am a developer by profession                                                   6080
# I am a student who is learning to code                                           1554
# I am not primarily a developer, but I write code sometimes as part of my work     444
# I code primarily as a hobby                                                       191
# I used to be a developer by profession, but no longer am                          115
# Name: MainBranch, dtype: int64

# %%
country_grp["MainBranch"].value_counts().loc["Turkey"]
# Out:
# MainBranch
# I am a developer by profession                                                   567
# I am a student who is learning to code                                            99
# I am not primarily a developer, but I write code sometimes as part of my work     51
# I code primarily as a hobby                                                       39
# I used to be a developer by profession, but no longer am                          20
# Name: MainBranch, dtype: int64

# %%
country_grp["MainBranch"].value_counts().loc["United States"]
# Out:
# MainBranch
# I am a developer by profession                                                   9456
# I am not primarily a developer, but I write code sometimes as part of my work    1272
# I am a student who is learning to code                                           1024
# I code primarily as a hobby                                                       449
# I used to be a developer by profession, but no longer am                          237
# Name: MainBranch, dtype: int64

# %%
country_grp["MainBranch"].value_counts().loc["Austria"]
# Out:
# MainBranch
# I am a developer by profession                                                   372
# I am a student who is learning to code                                            73
# I am not primarily a developer, but I write code sometimes as part of my work     65
# I code primarily as a hobby                                                       20
# I used to be a developer by profession, but no longer am                           7
# Name: MainBranch, dtype: int64

# %%
country_grp = df.groupby("Country")

# %%
country_grp["ConvertedComp"].count()
# Out:
# Country
# Afghanistan                                    24
# Albania                                        20
# Algeria                                        16
# Andorra                                         2
# Angola                                          2
# Antigua and Barbuda                             0
# Argentina                                     239
# Armenia                                        28
# Australia                                     772
# Austria                                       313
# Azerbaijan                                     21
# Bahamas                                         2
# Bahrain                                         4
# Bangladesh                                    184
# Barbados                                        2
# Belarus                                        75
# Belgium                                       257
# Belize                                          1
# Benin                                           2
# ...

# %%
type(country_grp["ConvertedComp"])
# Out:
# pandas.core.groupby.groupby.SeriesGroupBy

# %%
country_grp["ConvertedComp"].value_counts().loc["Afghanistan"]
# Out:
# ConvertedComp
# 1000000.0    3
# 23328.0      2
# 0.0          1
# 109.0        1
# 780.0        1
# 1860.0       1
# 2328.0       1
# 4356.0       1
# 4509.0       1
# 4668.0       1
# 5448.0       1
# 8016.0       1
# 10884.0      1
# 13992.0      1
# 16335.0      1
# 18000.0      1
# 18660.0      1
# 20220.0      1
# 20950.0      1
# 130000.0     1
# 231192.0     1
# Name: ConvertedComp, dtype: int64

# %%
country_grp.get_group("India")["ConvertedComp"].median()
# Out:
# 10056.0

# %%
country_grp.get_group("Brazil")["ConvertedComp"].median()
# Out:
# 17184.0

# %%
country_grp["ConvertedComp"].median().head(10)
# Out:
# Country
# Afghanistan            15163.5
# Albania                15900.0
# Algeria                 9432.0
# Andorra                88640.0
# Angola                  5292.0
# Antigua and Barbuda        NaN
# Argentina              17520.0
# Armenia                21066.0
# Australia              76831.0
# Austria                51888.0
# Name: ConvertedComp, dtype: float64

# %%
country_grp["ConvertedComp"].median().loc["India"]
# Out:
# 10056.0

# %%
country_grp["ConvertedComp"].median().loc["Afghanistan"]
# Out:
# 15163.5

# %%
country_grp.get_group("Afghanistan")["ConvertedComp"].median()
# Out:
# 15163.5

# %%
country_grp.get_group("Afghanistan").median()
# Out:
# Age                 23.0
# CompTotal        65000.0
# ConvertedComp    15163.5
# WorkWeekHrs         46.5
# dtype: float64

# %%
country_grp["ConvertedComp"].median().loc["United Kingdom"]
# Out:
# 67215.0

# %%
country_grp["ConvertedComp"].median().loc["Germany"]
# Out:
# 62697.0

# %%
country_grp["ConvertedComp"].describe()
# Out:
#                                             count           mean  \
# Country
# Afghanistan                                  24.0  148290.125000
# Albania                                      20.0   25611.000000
# Algeria                                      16.0   10362.812500
# Andorra                                       2.0   88640.000000
# Angola                                        2.0    5292.000000
# Antigua and Barbuda                           0.0            NaN
# Argentina                                   239.0   29010.033473
# Armenia                                      28.0   30421.285714
# Australia                                   772.0  146165.814767
# Austria                                     313.0   83077.661342
# Azerbaijan                                   21.0   14909.142857
# Bahamas                                       2.0   86706.000000
# Bahrain                                       4.0   39592.000000
# ...

# %%
country_grp["ConvertedComp"].describe().loc["India"]
# Out:
# count    2.668000e+03
# mean     2.875127e+04
# std      9.301753e+04
# min      0.000000e+00
# 25%      5.196000e+03
# 50%      1.005600e+04
# 75%      2.010000e+04
# max      1.800000e+06
# Name: India, dtype: float64

# %%
country_grp["ConvertedComp"].agg(["median", "mean"])
# Out:
#                                              median           mean
# Country
# Afghanistan                                 15163.5  148290.125000
# Albania                                     15900.0   25611.000000
# Algeria                                      9432.0   10362.812500
# Andorra                                     88640.0   88640.000000
# Angola                                       5292.0    5292.000000
# Antigua and Barbuda                             NaN            NaN
# Argentina                                   17520.0   29010.033473
# Armenia                                     21066.0   30421.285714
# Australia                                   76831.0  146165.814767
# Austria                                     51888.0   83077.661342
# Azerbaijan                                  11988.0   14909.142857
# Bahamas                                     86706.0   86706.000000
# Bahrain                                     40196.0   39592.000000
# ...

# %%
country_grp["ConvertedComp"].agg(["median", "mean"]).index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'United Kingdom', 'United Republic of Tanzania', 'United States',
#        'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country', length=183)

# %%
country_grp["ConvertedComp"].agg(["median", "mean"]).columns
# Out:
# Index(['median', 'mean'], dtype='object')

# %%
country_grp["ConvertedComp"].agg(["median", "mean"]).loc["India"]
# Out:
# median    10056.000000
# mean      28751.271364
# Name: India, dtype: float64

# %%
country_grp["ConvertedComp"].agg(["median", "mean"]).loc["Canada"]
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
country_grp["ConvertedComp"].get_group("India").median()
# Out:
# 10056.0

# %%
filt = (df["Country"] == "India") & df["LanguageWorkedWith"].str.contains("Python")

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 22                             I am a developer by profession      Yes   NaN
# 63                     I am a student who is learning to code      Yes  21.0
# 227                            I am a developer by profession      Yes  24.0
# 232                    I am a student who is learning to code       No  20.0
# 234                            I am a developer by profession      Yes  22.0
# 279                            I am a developer by profession      Yes   NaN
# 364                    I am a student who is learning to code      Yes  23.0
# 376                            I am a developer by profession      Yes   NaN
# 407                    I am a student who is learning to code      Yes  21.0
# 414                            I am a developer by profession      Yes  24.0
# 524         I am not primarily a developer, but I write co...      Yes  23.0
# ...

# %%
filt.head(5)
# Out:
# Respondent
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
type(filt)
# Out:
# pandas.core.series.Series

# %%
df.loc[filt, "LanguageWorkedWith"].count()
# Out:
# 2670

# %%
filt = df["Country"] == "India"
df.loc[filt]["LanguageWorkedWith"].head(5)
# Out:
# Respondent
# 7                            C#;HTML/CSS;PHP
# 22                               Java;Python
# 58              C#;JavaScript;SQL;TypeScript
# 63     C;C++;HTML/CSS;Java;JavaScript;Python
# 149           Bash/Shell/PowerShell;C++;Perl
# Name: LanguageWorkedWith, dtype: object

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python", na = False).head(5)
# Out:
# Respondent
# 7      False
# 22      True
# 58     False
# 63      True
# 149    False
# Name: LanguageWorkedWith, dtype: bool

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").value_counts()
# Out:
# False    4214
# True     2670
# Name: LanguageWorkedWith, dtype: int64

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 2670

# %%
country_grp = df.groupby("Country")

# %%
country_grp["LanguageWorkedWith"]

# %%
country_grp["LanguageWorkedWith"]

# %%
country_grp.get_group("India")["LanguageWorkedWith"].str.contains("Python").value_counts()
# Out:
# False    4214
# True     2670
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp["LanguageWorkedWith"]

# %%
country_grp["LanguageWorkedWith"].head(50)
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
# 6                                 HTML/CSS;Java;JavaScript
# 7                                          C#;HTML/CSS;PHP
# 8                                               Python;SQL
# 9                                  HTML/CSS;JavaScript;PHP
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 11                                     C#;JavaScript;Swift
# 12                                     HTML/CSS;JavaScript
# 13                                     C;JavaScript;Python
# 14                      HTML/CSS;JavaScript;SQL;TypeScript
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# 16       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...

# %%
country_grp["LanguageWorkedWith"]

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").value_counts()).head(5)
# Out:
# Country
# Afghanistan  False    37
#              True     11
# Albania      False    25
#              True     13
# Algeria      True     40
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
country_grp.get_group("Australia")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 401                            I am a developer by profession      Yes  34.0
# 2581                           I am a developer by profession      Yes  40.0
# 2627        I am not primarily a developer, but I write co...       No  38.0
# 3377                           I am a developer by profession      Yes  27.0
# 3455                           I am a developer by profession      Yes  39.0
# 3504                           I am a developer by profession      Yes  36.0
# 3628        I am not primarily a developer, but I write co...      Yes  34.0
# 3795                           I am a developer by profession      Yes  24.0
# 3840                           I am a developer by profession      Yes  25.0
# 3901                           I am a developer by profession      Yes   NaN
# 3943        I used to be a developer by profession, but no...      Yes   NaN
# ...

# %%
type(country_grp.get_group("Australia"))
# Out:
# pandas.core.frame.DataFrame

# %%
country_grp.get_group("India")["ConvertedComp"].head(10)
# Out:
# Respondent
# 7           NaN
# 22          NaN
# 58          NaN
# 63          NaN
# 149    293196.0
# 177         NaN
# 227     11728.0
# 232         NaN
# 234         NaN
# 268         NaN
# Name: ConvertedComp, dtype: float64

# %%
type(country_grp.get_group("India")["ConvertedComp"])
# Out:
# pandas.core.series.Series

# %%
country_grp["LanguageWorkedWith"]

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
type(country_grp)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
type(country_grp["Country"])
# Out:
# pandas.core.groupby.groupby.SeriesGroupBy

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
country_grp["LanguageWorkedWith"].str.contains("JavaScript")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-c9773c869b9d> in <module>
# ----> 1 country_grp["LanguageWorkedWith"].str.contains("JavaScript")
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("JavaScript").value_counts())
# Out:
# Country
# Afghanistan                           True       33
#                                       False      15
# Albania                               True       23
#                                       False      15
# Algeria                               True       56
#                                       False      22
# Andorra                               False       5
#                                       True        3
# Angola                                False       2
#                                       True        1
# Argentina                             True      257
#                                       False      91
# Armenia                               True       38
#                                       False      13
# Australia                             True      800
#                                       False     323
# Austria                               True      333
#                                       False     176
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("JavaScrip").sum()).head(10)
# Out:
# Country
# Afghanistan             33
# Albania                 23
# Algeria                 56
# Andorra                  3
# Angola                   1
# Antigua and Barbuda      0
# Argentina              257
# Armenia                 38
# Australia              800
# Austria                333
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                                    11
# Albania                                        13
# Algeria                                        40
# Andorra                                         3
# Angola                                          1
# Antigua and Barbuda                             0
# Argentina                                     134
# Armenia                                        17
# Australia                                     524
# Austria                                       205
# Azerbaijan                                     11
# Bahamas                                         1
# Bahrain                                         2
# Bangladesh                                    179
# Barbados                                        2
# Belarus                                        40
# Belgium                                       173
# Belize                                          2
# Benin                                           3
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").value_counts(normalize = True))
# Out:
# Country
# Afghanistan                           False    0.770833
#                                       True     0.229167
# Albania                               False    0.657895
#                                       True     0.342105
# Algeria                               True     0.512821
#                                       False    0.487179
# Andorra                               False    0.625000
#                                       True     0.375000
# Angola                                False    0.666667
#                                       True     0.333333
# Argentina                             False    0.614943
#                                       True     0.385057
# Armenia                               False    0.666667
#                                       True     0.333333
# Australia                             False    0.533393
#                                       True     0.466607
# Austria                               False    0.597250
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").value_counts(normalize = True))
# Out:
# Country
# Afghanistan                           False    0.770833
#                                       True     0.229167
# Albania                               False    0.657895
#                                       True     0.342105
# Algeria                               True     0.512821
#                                       False    0.487179
# Andorra                               False    0.625000
#                                       True     0.375000
# Angola                                False    0.666667
#                                       True     0.333333
# Argentina                             False    0.614943
#                                       True     0.385057
# Armenia                               False    0.666667
#                                       True     0.333333
# Australia                             False    0.533393
#                                       True     0.466607
# Austria                               False    0.597250
# ...

# %%
country_respondents = df["Country"].value_counts()

# %%
country_respondents.head(10)
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# France             1898
# Brazil             1818
# Netherlands        1343
# Poland             1278
# Australia          1208
# Name: Country, dtype: int64

# %%
country_uses_python = country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("Python").sum())
country_uses_python.head(10)
# Out:
# Country
# Afghanistan             11
# Albania                 13
# Algeria                 40
# Andorra                  3
# Angola                   1
# Antigua and Barbuda      0
# Argentina              134
# Armenia                 17
# Australia              524
# Austria                205
# Name: LanguageWorkedWith, dtype: int64

# %%
country_uses_python["United States"]
# Out:
# 5964

# %%
python_df = pd.concat([country_respondents, country_uses_python])

# %%
python_df.head(10)
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
# France             1898
# Brazil             1818
# Netherlands        1343
# Poland             1278
# Australia          1208
# dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis = "columns")
python_df.head(10)
# Out:
# C:\Users\DeViL-AnGeL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                      Country  LanguageWorkedWith
# Afghanistan               84                  11
# Albania                   54                  13
# Algeria                   94                  40
# Andorra                   13                   3
# Angola                     9                   1
# Antigua and Barbuda        2                   0
# Argentina                395                 134
# Armenia                   64                  17
# Australia               1208                 524
# Austria                  539                 205

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis = "columns", sort = False)
python_df.head(10)
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# France             1898                 833
# Brazil             1818                 635
# Netherlands        1343                 544
# Poland             1278                 509
# Australia          1208                 524

# %%
python_df.rename(columns = {"Country" : "NumRespondents", "LanguageWorkedWith" : "NumKnowsPython"}, inplace = True)

# %%
python_df.head(10)
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12469            5964
# India                     8403            2670
# United Kingdom            3896            1621
# Germany                   3890            1712
# Canada                    2191            1011
# France                    1898             833
# Brazil                    1818             635
# Netherlands               1343             544
# Poland                    1278             509
# Australia                 1208             524

# %%
python_df["PctKnowsPython"] = (python_df["NumKnowsPython"] / python_df["NumRespondents"]) * 100
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# United States                                12469            5964
# India                                         8403            2670
# United Kingdom                                3896            1621
# Germany                                       3890            1712
# Canada                                        2191            1011
# France                                        1898             833
# Brazil                                        1818             635
# Netherlands                                   1343             544
# Poland                                        1278             509
# Australia                                     1208             524
# Spain                                         1161             448
# Italy                                         1117             422
# Russian Federation                            1092             421
# ...

# %%
python_df.sort_values(by = "PctKnowsPython", ascending = False, inplace = True)
python_df
# Out:
#                                     NumRespondents  NumKnowsPython  \
# Micronesia, Federated States of...               1               1
# Saint Lucia                                      1               1
# Gabon                                            1               1
# Montenegro                                      13               9
# Brunei Darussalam                                3               2
# Guyana                                           5               3
# Swaziland                                        7               4
# Iceland                                         53              28
# Finland                                        349             183
# Uganda                                          81              42
# Belize                                           4               2
# Papua New Guinea                                 2               1
# Jamaica                                         14               7
# ...

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Micronesia, Federated States of...                 1               1
# Saint Lucia                                        1               1
# Gabon                                              1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Belize                                             4               2
# Papua New Guinea                                   2               1
# Jamaica                                           14               7
# ...

# %%
python_df.loc["Japan"]
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
country_grp = df.groupby(by = "Country")
country_grp

# %%
JavaScript_known = country_grp["LanguageWorkedWith"].apply(lambda x : x.str.contains("JavaScrip").sum())

# %%
country_respondents = df["Country"].value_counts()

# %%
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
# France                                 1898
# Brazil                                 1818
# Netherlands                            1343
# Poland                                 1278
# Australia                              1208
# Spain                                  1161
# Italy                                  1117
# Russian Federation                     1092
# Sweden                                  886
# Pakistan                                809
# Turkey                                  777
# Israel                                  653
# Switzerland                             629
# Bangladesh                              609
# Romania                                 604
# Nigeria                                 593
# ...

# %%
javascript_df = pd.concat([country_respondents, JavaScript_known])
javascript_df
# Out:
# United States                                12469
# India                                         8403
# United Kingdom                                3896
# Germany                                       3890
# Canada                                        2191
# France                                        1898
# Brazil                                        1818
# Netherlands                                   1343
# Poland                                        1278
# Australia                                     1208
# Spain                                         1161
# Italy                                         1117
# Russian Federation                            1092
# Sweden                                         886
# Pakistan                                       809
# Turkey                                         777
# Israel                                         653
# Switzerland                                    629
# ...

# %%
javascript_df = pd.concat([country_respondents, JavaScript_known], axis = "columns")
javascript_df
# Out:
# C:\Users\DeViL-AnGeL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                            Country  LanguageWorkedWith
# Afghanistan                                     84                  33
# Albania                                         54                  23
# Algeria                                         94                  56
# Andorra                                         13                   3
# Angola                                           9                   1
# Antigua and Barbuda                              2                   0
# Argentina                                      395                 257
# ...

# %%
javascript_df = pd.concat([country_respondents, JavaScript_known], axis = "columns", sort = False)
javascript_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                8156
# India                                  8403                4451
# United Kingdom                         3896                2422
# Germany                                3890                2249
# Canada                                 2191                1432
# France                                 1898                1183
# Brazil                                 1818                1149
# Netherlands                            1343                 882
# Poland                                 1278                 704
# Australia                              1208                 800
# Spain                                  1161                 699
# Italy                                  1117                 717
# Russian Federation                     1092                 543
# Sweden                                  886                 525
# ...

# %%
javascript_df.rename(columns = {"Country" : "NumRespondents", "LanguageWorkedWith" : "NumKnownJavaScript"}, inplace = True)

# %%
javascript_df
# Out:
#                                     NumRespondents  NumKnownJavaScript
# United States                                12469                8156
# India                                         8403                4451
# United Kingdom                                3896                2422
# Germany                                       3890                2249
# Canada                                        2191                1432
# France                                        1898                1183
# Brazil                                        1818                1149
# Netherlands                                   1343                 882
# Poland                                        1278                 704
# Australia                                     1208                 800
# Spain                                         1161                 699
# Italy                                         1117                 717
# ...

# %%
javascript_df["PctKnowsPython"] = (javascript_df["NumKnownJavaScript"] / javascript_df["NumRespondents"]) * 100

# %%
javascript_df
# Out:
#                                     NumRespondents  NumKnownJavaScript  \
# United States                                12469                8156
# India                                         8403                4451
# United Kingdom                                3896                2422
# Germany                                       3890                2249
# Canada                                        2191                1432
# France                                        1898                1183
# Brazil                                        1818                1149
# Netherlands                                   1343                 882
# Poland                                        1278                 704
# Australia                                     1208                 800
# Spain                                         1161                 699
# Italy                                         1117                 717
# ...

# %%
javascript_df.sort_values(by = "PctKnowsPython", ascending = False, inplace = True)

# %%
javascript_df.head(10)
# Out:
#                                     NumRespondents  NumKnownJavaScript  \
# Micronesia, Federated States of...               1                   1
# Lesotho                                          1                   1
# Brunei Darussalam                                3                   3
# Papua New Guinea                                 2                   2
# Saint Lucia                                      1                   1
# San Marino                                       2                   2
# Nauru                                            1                   1
# Gabon                                            1                   1
# Chad                                             1                   1
# Grenada                                          1                   1
#
#                                     PctKnowsPython
# Micronesia, Federated States of...           100.0
# Lesotho                                      100.0
# ...
