# %%
import pandas as pd

# %%
people = {
    "first" : ["Lalit", "Suraj", "Ankit", "Vikash", "Shohel"],
    "last" : ["Siraswa", "Dhadeech", "Verma", "Tawar", "Khan"],
    "email" : ["lalitsiraswa@gmail.com", "surajdhadeech@gmail.com", "ankitverma@gmail.com", "vikashtawar@gmail.com", "shohelkhan@gmail.com"]
}

# %%
df = pd.DataFrame(data = people)
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit     Verma     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel      Khan     shohelkhan@gmail.com

# %%
# print(df.sort_index().head(2), "\n")
# print(df.sort_values("first").tail(2), "\n")
# print(df.sort_values("last").head(2), "\n")

# %%
print(df.sort_values(by = "first"), "\n")
print(df.sort_values(by = "first", ascending = False), "\n")
print(df.sort_values(by = "last"), "\n")
print(df.sort_values(by = "last", ascending = False), "\n")
# Out:
#     first      last                    email
# 2   Ankit     Verma     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel      Khan     shohelkhan@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
#
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 4  Shohel      Khan     shohelkhan@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit     Verma     ankitverma@gmail.com
#
#     first      last                    email
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 4  Shohel      Khan     shohelkhan@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 2   Ankit     Verma     ankitverma@gmail.com
#
#     first      last                    email
# 2   Ankit     Verma     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# ...

# %%
people = {
    "first" : ["Lalit", "Suraj", "Ankit", "Vikash", "Shohel"],
    "last" : ["Siraswa", "Dhadeech", "Siraswa", "Tawar", "Siraswa"],
    "email" : ["lalitsiraswa@gmail.com", "surajdhadeech@gmail.com", "ankitverma@gmail.com", "vikashtawar@gmail.com", "shohelkhan@gmail.com"]
}

# %%
df = pd.DataFrame(data = people)
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = "last")
# Out:
#     first      last                    email
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com

# %%
df.sort_values(by = "last", ascending = False)
# Out:
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = ["last", "first"])
# Out:
#     first      last                    email
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = ["last", "first"], ascending = False)
# Out:
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = ["last", "first"], ascending = [False, True])
# Out:
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = "first")
# Out:
#     first      last                    email
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com

# %%
df.sort_values(by = "last")
# Out:
#     first      last                    email
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com

# %%
df.sort_values(by = ["last", "first"])
# Out:
#     first      last                    email
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com

# %%
df.sort_values(by = ["last", "first"], ascending = False)
# Out:
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
df.sort_values(by = ["last", "first"], ascending = [False, True])
# Out:
#     first      last                    email
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com

# %%
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
print(df.loc[0], "\n")
print(df.loc[0].index, "\n")
# Out:
# first                     Lalit
# last                    Siraswa
# email    lalitsiraswa@gmail.com
# Name: 0, dtype: object
#
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.sort_index(ascending = False, inplace = True)
df
# Out:
#     first      last                    email
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com

# %%
df.sort_index(inplace = True)
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com

# %%
print(df["first"].sort_values(), "\n")
print(df["last"].sort_values(), "\n")
print(df["email"].sort_values(), "\n")
# Out:
# 2     Ankit
# 0     Lalit
# 4    Shohel
# 1     Suraj
# 3    Vikash
# Name: first, dtype: object
#
# 1    Dhadeech
# 0     Siraswa
# 2     Siraswa
# 4     Siraswa
# 3       Tawar
# Name: last, dtype: object
#
# 2       ankitverma@gmail.com
# 0     lalitsiraswa@gmail.com
# 4       shohelkhan@gmail.com
# 1    surajdhadeech@gmail.com
# 3      vikashtawar@gmail.com
# Name: email, dtype: object

# %%
df.sort_index(ascending = False, inplace = True)

# %%
df
# Out:
#     first      last                    email
# 4  Shohel   Siraswa     shohelkhan@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com

# %%
df["first"].sort_index()
# Out:
# 0     Lalit
# 1     Suraj
# 2     Ankit
# 3    Vikash
# 4    Shohel
# Name: first, dtype: object

# %%
df["last"].sort_index()
# Out:
# 0     Siraswa
# 1    Dhadeech
# 2     Siraswa
# 3       Tawar
# 4     Siraswa
# Name: last, dtype: object

# %%
df["email"].sort_index()
# Out:
# 0     lalitsiraswa@gmail.com
# 1    surajdhadeech@gmail.com
# 2       ankitverma@gmail.com
# 3      vikashtawar@gmail.com
# 4       shohelkhan@gmail.com
# Name: email, dtype: object

# %%
df.sort_index(inplace = True)
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit   Siraswa     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel   Siraswa     shohelkhan@gmail.com
