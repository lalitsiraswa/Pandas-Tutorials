# %%
import pandas as pd

# %%
people = {
    "first" : ["Lalit", "Suraj", "Ankit", "Vikash", "Shohel"],
    "last" : ["Siraswa", "Dhadeech", "Verma", "Tawar", "Khan"],
    "email" : ["lalitsiraswa@gmail.com", "surajdhadeech@gmail.com", "ankitverma@gmail.com", "vikashtawar@gmail.com", "shohelkhan@gmail.com"]
}

# %%
df = pd.DataFrame(data = people)
df
# Out:
#     first      last                    email
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com
# 2   Ankit     Verma     ankitverma@gmail.com
# 3  Vikash     Tawar    vikashtawar@gmail.com
# 4  Shohel      Khan     shohelkhan@gmail.com

# %%
df["full_name"] = df["first"] + " " + df["last"]
df
# Out:
#     first      last                    email       full_name
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan

# %%
df["length"] = df["full_name"].apply(len)

# %%
df
# Out:
#     first      last                    email       full_name  length
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma      11
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar      12
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan      11

# %%
df["last"].replace({"Siraswa" : "Kumawat"})
# Out:
# 0     Kumawat
# 1    Dhadeech
# 2       Verma
# 3       Tawar
# 4        Khan
# Name: last, dtype: object

# %%
df.drop(columns = ["first", "last"])
# Out:
#                      email       full_name  length
# 0   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2     ankitverma@gmail.com     Ankit Verma      11
# 3    vikashtawar@gmail.com    Vikash Tawar      12
# 4     shohelkhan@gmail.com     Shohel Khan      11

# %%
df
# Out:
#     first      last                    email       full_name  length
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma      11
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar      12
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan      11

# %%
# df.drop(columns = "first")

# %%
# df.drop(columns = "last")

# %%
df
# Out:
#     first      last                    email       full_name  length
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma      11
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar      12
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan      11

# %%
df["full_name"].str.split(" ")
# Out:
# 0     [Lalit, Siraswa]
# 1    [Suraj, Dhadeech]
# 2       [Ankit, Verma]
# 3      [Vikash, Tawar]
# 4       [Shohel, Khan]
# Name: full_name, dtype: object

# %%
# df.drop(columns = ["first", "last"], inplace = True)

# %%
df
# Out:
#     first      last                    email       full_name  length
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma      11
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar      12
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan      11

# %%
print(df["full_name"].str.split(" "), "\n")
print(df["full_name"].str.split(" ", expand = True), "\n")
# Out:
# 0     [Lalit, Siraswa]
# 1    [Suraj, Dhadeech]
# 2       [Ankit, Verma]
# 3      [Vikash, Tawar]
# 4       [Shohel, Khan]
# Name: full_name, dtype: object
#
#         0         1
# 0   Lalit   Siraswa
# 1   Suraj  Dhadeech
# 2   Ankit     Verma
# 3  Vikash     Tawar
# 4  Shohel      Khan

# %%
df
# Out:
#     first      last                    email       full_name  length
# 0   Lalit   Siraswa   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1   Suraj  Dhadeech  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2   Ankit     Verma     ankitverma@gmail.com     Ankit Verma      11
# 3  Vikash     Tawar    vikashtawar@gmail.com    Vikash Tawar      12
# 4  Shohel      Khan     shohelkhan@gmail.com     Shohel Khan      11

# %%
print(df["full_name"].str.split(" "), "\n")
print(df["full_name"].str.split(" ", expand = True))
# Out:
# 0     [Lalit, Siraswa]
# 1    [Suraj, Dhadeech]
# 2       [Ankit, Verma]
# 3      [Vikash, Tawar]
# 4       [Shohel, Khan]
# Name: full_name, dtype: object
#
#         0         1
# 0   Lalit   Siraswa
# 1   Suraj  Dhadeech
# 2   Ankit     Verma
# 3  Vikash     Tawar
# 4  Shohel      Khan

# %%
df["full_name"].str.split(" ", expand = True)
# Out:
#         0         1
# 0   Lalit   Siraswa
# 1   Suraj  Dhadeech
# 2   Ankit     Verma
# 3  Vikash     Tawar
# 4  Shohel      Khan

# %%
df.drop(columns = ["first", "last"], inplace = True)

# %%
df
# Out:
#                      email       full_name  length
# 0   lalitsiraswa@gmail.com   Lalit Siraswa      13
# 1  surajdhadeech@gmail.com  Suraj Dhadeech      14
# 2     ankitverma@gmail.com     Ankit Verma      11
# 3    vikashtawar@gmail.com    Vikash Tawar      12
# 4     shohelkhan@gmail.com     Shohel Khan      11

# %%
df[["first", "last"]] = df["full_name"].str.split(" ", expand = True)
df
# Out:
#                      email       full_name  length   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa      13   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech      14   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma      11   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar      12  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan      11  Shohel      Khan

# %%
df["first"], df["last"]
# Out:
# (0     Lalit
#  1     Suraj
#  2     Ankit
#  3    Vikash
#  4    Shohel
#  Name: first, dtype: object, 0     Siraswa
#  1    Dhadeech
#  2       Verma
#  3       Tawar
#  4        Khan
#  Name: last, dtype: object)

# %%
df
# Out:
#                      email       full_name  length   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa      13   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech      14   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma      11   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar      12  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan      11  Shohel      Khan

# %%
df.loc[5] = ["mukuljangir@gmail.com", "Mukul Jangir", len("Mukul Jangir"), "Mukul", "Jangir"]
df
# Out:
#                      email       full_name  length   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa      13   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech      14   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma      11   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar      12  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan      11  Shohel      Khan
# 5    mukuljangir@gmail.com    Mukul Jangir      12   Mukul    Jangir

# %%
df.drop(columns = ["length"], inplace = True)
df
# Out:
#                      email       full_name   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan  Shohel      Khan
# 5    mukuljangir@gmail.com    Mukul Jangir   Mukul    Jangir

# %%
df.drop(index = [5], inplace = True)
df
# Out:
#                      email       full_name   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan  Shohel      Khan

# %%
df = df.append({"first" : "Mukul", "last" : "Jangir"}, ignore_index = True)

# %%
people = {
    "first" : ["Aman", "Gourav"],
    "last" : ["Agrawal", "Sain"],
    "email" : ["amanagrawal@gmail.com", "gouravsain@gmail.com"]
}

# %%
df2 = pd.DataFrame(data = people)
df2
# Out:
#     first     last                  email
# 0    Aman  Agrawal  amanagrawal@gmail.com
# 1  Gourav     Sain   gouravsain@gmail.com

# %%
df
# Out:
#                      email       full_name   first      last
# 0   lalitsiraswa@gmail.com   Lalit Siraswa   Lalit   Siraswa
# 1  surajdhadeech@gmail.com  Suraj Dhadeech   Suraj  Dhadeech
# 2     ankitverma@gmail.com     Ankit Verma   Ankit     Verma
# 3    vikashtawar@gmail.com    Vikash Tawar  Vikash     Tawar
# 4     shohelkhan@gmail.com     Shohel Khan  Shohel      Khan
# 5                      NaN             NaN   Mukul    Jangir

# %%
df.append(df2)
# Out:
# C:\Users\DeViL-AnGeL\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa   Siraswa
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan
# 5                      NaN   Mukul             NaN    Jangir
# 0    amanagrawal@gmail.com    Aman             NaN   Agrawal
# 1     gouravsain@gmail.com  Gourav             NaN      Sain

# %%
df.append(df2, ignore_index = True, sort = True)
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa   Siraswa
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan
# 5                      NaN   Mukul             NaN    Jangir
# 6    amanagrawal@gmail.com    Aman             NaN   Agrawal
# 7     gouravsain@gmail.com  Gourav             NaN      Sain

# %%
df = df.append(df2, ignore_index = True, sort = True)

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa   Siraswa
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan
# 5                      NaN   Mukul             NaN    Jangir
# 6    amanagrawal@gmail.com    Aman             NaN   Agrawal
# 7     gouravsain@gmail.com  Gourav             NaN      Sain

# %%
df.loc[5, "email"] = "mukuljangir@gmail.com"

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa   Siraswa
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan
# 5    mukuljangir@gmail.com   Mukul             NaN    Jangir
# 6    amanagrawal@gmail.com    Aman             NaN   Agrawal
# 7     gouravsain@gmail.com  Gourav             NaN      Sain

# %%
df.drop(index = [5, 6, 7], inplace = True)

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa   Siraswa
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
df.loc[0, "last"] = "Verma"

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa     Verma
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
df[df["last"] == "Verma"].index
# Out:
# Int64Index([0, 2], dtype='int64')

# %%
df.drop(index = df[df["last"] == "Verma"].index)
# Out:
#                      email   first       full_name      last
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa     Verma
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
filt = df["last"] == "Verma"
print(df[filt], "\n")
print(df[filt].index, "\n")
df.drop(index = df[filt].index)
# Out:
#                     email  first      full_name   last
# 0  lalitsiraswa@gmail.com  Lalit  Lalit Siraswa  Verma
# 2    ankitverma@gmail.com  Ankit    Ankit Verma  Verma
#
# Int64Index([0, 2], dtype='int64')
#                      email   first       full_name      last
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
df
# Out:
#                      email   first       full_name      last
# 0   lalitsiraswa@gmail.com   Lalit   Lalit Siraswa     Verma
# 1  surajdhadeech@gmail.com   Suraj  Suraj Dhadeech  Dhadeech
# 2     ankitverma@gmail.com   Ankit     Ankit Verma     Verma
# 3    vikashtawar@gmail.com  Vikash    Vikash Tawar     Tawar
# 4     shohelkhan@gmail.com  Shohel     Shohel Khan      Khan

# %%
print(df.loc[0], "\n")
print(df.loc[0].index, "\n")
# Out:
# email        lalitsiraswa@gmail.com
# first                         Lalit
# full_name             Lalit Siraswa
# last                          Verma
# Name: 0, dtype: object
#
# Index(['email', 'first', 'full_name', 'last'], dtype='object')
