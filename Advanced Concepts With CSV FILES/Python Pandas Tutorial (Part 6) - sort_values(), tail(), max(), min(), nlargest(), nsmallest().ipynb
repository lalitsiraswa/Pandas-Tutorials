# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 60)
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.sort_values("Country").head(2)
# Out:
#                                         MainBranch Hobbyist  Age  \
# Respondent
# 8631        I am a student who is learning to code       No  NaN
# 25001               I am a developer by profession       No  NaN
#
#                       Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 8631                          19      NaN        NaN            NaN
# 25001       Younger than 5 years   Weekly        NaN            NaN
#
#                 Country                 CurrencyDesc CurrencySymbol  \
# Respondent
# 8631        Afghanistan                          NaN            NaN
# 25001       Afghanistan  United Arab Emirates dirham            AED
#
#            DatabaseDesireNextYear DatabaseWorkedWith  \
# Respondent
# 8631                      MongoDB              MySQL
# 25001                         NaN          Cassandra
#
#                                            DevType  \
# Respondent
# 8631        Developer, front-end;Developer, mobile
# ...

# %%
df[["Country", "ConvertedComp"]].sort_values(by = "Country").head(2)
# Out:
#                 Country  ConvertedComp
# Respondent
# 8631        Afghanistan            NaN
# 25001       Afghanistan            NaN

# %%
df["ConvertedComp"].tail(5)
# Out:
# Respondent
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: ConvertedComp, dtype: float64

# %%
df["ConvertedComp"].sort_values(ascending = False).head(5)
# Out:
# Respondent
# 57863    2000000.0
# 15529    2000000.0
# 58040    2000000.0
# 15556    2000000.0
# 2135     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df[["Country", "ConvertedComp"]].sort_values(by = ["Country", "ConvertedComp"], ascending = [True, False]).head(2)
# Out:
#                 Country  ConvertedComp
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0

# %%
df["ConvertedComp"].max()
# Out:
# 2000000.0

# %%
df["ConvertedComp"].nlargest(5)
# Out:
# Respondent
# 123    2000000.0
# 125    2000000.0
# 193    2000000.0
# 665    2000000.0
# 699    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df["ConvertedComp"].nlargest(10).index
# Out:
# Int64Index([123, 125, 193, 665, 699, 724, 818, 986, 1022, 1036], dtype='int64', name='Respondent')

# %%
df.nlargest(10, "ConvertedComp")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
# 724         I am not primarily a developer, but I write co...      Yes   NaN
# 818         I am not primarily a developer, but I write co...      Yes  40.0
# 986                            I am a developer by profession      Yes  27.0
# 1022                           I am a developer by profession      Yes  34.0
# 1036                           I am a developer by profession      Yes  26.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# ...

# %%
df.iloc[df["ConvertedComp"].nlargest(10).index]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 127                            I am a developer by profession       No  64.0
# 195                            I am a developer by profession      Yes  26.0
# 667                            I am a developer by profession       No   NaN
# 701                            I am a developer by profession      Yes  37.0
# 726                            I am a developer by profession      Yes  45.0
# 820                    I am a student who is learning to code      Yes  30.0
# 990         I am not primarily a developer, but I write co...       No  30.0
# 1026                           I am a developer by profession      Yes  22.0
# 1040                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp         Country  \
# Respondent
# ...

# %%
df["ConvertedComp"].nsmallest(10)
# Out:
# Respondent
# 124     0.0
# 238     0.0
# 884     0.0
# 1116    0.0
# 1278    0.0
# 1794    0.0
# 2073    0.0
# 2196    0.0
# 2248    0.0
# 2323    0.0
# Name: ConvertedComp, dtype: float64

# %%
df.nsmallest(10, "ConvertedComp")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 124                            I am a developer by profession       No  38.0
# 238         I am not primarily a developer, but I write co...      Yes   NaN
# 884                            I am a developer by profession      Yes  41.0
# 1116                           I am a developer by profession      Yes  25.0
# 1278                           I am a developer by profession      Yes  21.0
# 1794                           I am a developer by profession      Yes   NaN
# 2073                           I am a developer by profession      Yes  27.0
# 2196                           I am a developer by profession      Yes   NaN
# 2248                           I am a developer by profession       No   NaN
# 2323                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp              Country  \
# Respondent
# ...

# %%
df["ConvertedComp"].nsmallest(10)
# Out:
# Respondent
# 124     0.0
# 238     0.0
# 884     0.0
# 1116    0.0
# 1278    0.0
# 1794    0.0
# 2073    0.0
# 2196    0.0
# 2248    0.0
# 2323    0.0
# Name: ConvertedComp, dtype: float64

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
df.loc[df["ConvertedComp"].nsmallest(10).index]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 124                            I am a developer by profession       No  38.0
# 238         I am not primarily a developer, but I write co...      Yes   NaN
# 884                            I am a developer by profession      Yes  41.0
# 1116                           I am a developer by profession      Yes  25.0
# 1278                           I am a developer by profession      Yes  21.0
# 1794                           I am a developer by profession      Yes   NaN
# 2073                           I am a developer by profession      Yes  27.0
# 2196                           I am a developer by profession      Yes   NaN
# 2248                           I am a developer by profession       No   NaN
# 2323                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp              Country  \
# Respondent
# ...
