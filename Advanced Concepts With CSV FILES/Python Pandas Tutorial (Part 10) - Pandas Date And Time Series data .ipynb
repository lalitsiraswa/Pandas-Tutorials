# %%
import pandas as pd
import numpy as np

# %%
d_parser = lambda x : pd.datetime.strptime(x, "%Y-%m-%d %I-%p")
df = pd.read_csv("data/ETH_1h.csv", parse_dates = ["Date"], date_parser = d_parser)
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.shape
# Out:
# (23674, 7)

# %%
df.loc[0, "Date"]
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
 df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Symbol            object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d %I-%p")

# %%
df.loc[0, "Date"]
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].head()
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Symbol            object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %%
df["Date"].head()
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
df["Date"].dt.day_name().head()
# Out:
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday
# Name: Date, dtype: object

# %%
df["Date"].dt.day_name().head(2)
# Out:
# 0    Friday
# 1    Friday
# Name: Date, dtype: object

# %%
df["DayOfWeek"] = df["Date"].dt.day_name()

# %%
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
df.loc[df.index.min()]
# Out:
# Date         2020-03-13 20:00:00
# Symbol                    ETHUSD
# Open                      129.94
# High                      131.82
# Low                       126.87
# Close                     128.71
# Volume               1.94067e+06
# DayOfWeek                 Friday
# Name: 0, dtype: object

# %%
df.loc[df.index.max()]
# Out:
# Date         2017-07-01 11:00:00
# Symbol                    ETHUSD
# Open                      279.98
# High                      279.99
# Low                        272.1
# Close                     275.01
# Volume                    679359
# DayOfWeek               Saturday
# Name: 23673, dtype: object

# %%
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].max() - df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08
# 5     2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85
# 6     2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39
# 7     2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03
# 8     2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35
# 9     2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93
# 10    2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60
# 11    2020-03-13 09:00:00  ETHUSD  127.12  136.53  126.62  133.80
# 12    2020-03-13 08:00:00  ETHUSD  127.57  133.10  121.94  127.12
# ...

# %%
df[df["Date"] >= "2020-01-01 00:00:00"]
# Out:
#                     Date  Symbol    Open    High     Low   Close       Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 5    2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 6    2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 7    2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 8    2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 9    2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 10   2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# ...

# %%
df.head(1750)
# Out:
#                     Date  Symbol    Open    High     Low   Close       Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 5    2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 6    2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 7    2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 8    2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 9    2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 10   2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# ...

# %%
filt = df["Date"] >= "2020"
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close       Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 5    2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 6    2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 7    2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 8    2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 9    2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 10   2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# ...

# %%
filt = ("2019" <= df["Date"]) & (df["Date"] < "2020")
df.loc[filt].count()
# Out:
# Date         8760
# Symbol       8760
# Open         8760
# High         8760
# Low          8760
# Close        8760
# Volume       8760
# DayOfWeek    8760
# dtype: int64

# %%
filt = (df["Date"] < "2020") & (df["Date"] >= "2019")
df.loc[filt].count()
# Out:
# Date         8760
# Symbol       8760
# Open         8760
# High         8760
# Low          8760
# Close        8760
# Volume       8760
# DayOfWeek    8760
# dtype: int64

# %%
filt = (df["Date"] >= pd.to_datetime("2019-01-01")) & (df["Date"] < pd.to_datetime("2020-01-01"))
df.loc[filt].count()
# Out:
# Date         8760
# Symbol       8760
# Open         8760
# High         8760
# Low          8760
# Close        8760
# Volume       8760
# DayOfWeek    8760
# dtype: int64

# %%
df.set_index("Date", inplace = True)

# %%
df.loc["2019" : "2019-12-31"].count()
# Out:
# Symbol       8760
# Open         8760
# High         8760
# Low          8760
# Close        8760
# Volume       8760
# DayOfWeek    8760
# dtype: int64

# %%
df.loc["2019"].count()
# Out:
# Symbol       8760
# Open         8760
# High         8760
# Low          8760
# Close        8760
# Volume       8760
# DayOfWeek    8760
# dtype: int64

# %%
df.loc["2020-01" : "2020-02"].count()
# Out:
# Symbol       1440
# Open         1440
# High         1440
# Low          1440
# Close        1440
# Volume       1440
# DayOfWeek    1440
# dtype: int64

# %%
df.loc["2020-01" : "2020-02"]["Close"].mean()
# Out:
# 195.16559027777814

# %%
df.loc["2020-01-01"]["High"].max()
# Out:
# 132.68

# %%
df.loc["2020-01" : "2020-02"]["High"].head(5)
# Out:
# Date
# 2020-02-29 23:00:00    223.58
# 2020-02-29 22:00:00    223.59
# 2020-02-29 21:00:00    225.14
# 2020-02-29 20:00:00    225.33
# 2020-02-29 19:00:00    225.85
# Name: High, dtype: float64

# %%
df.loc["2020-01" : "2020-02"].head(24).head(4)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
#
#                     DayOfWeek
# Date
# 2020-02-29 23:00:00  Saturday
# 2020-02-29 22:00:00  Saturday
# 2020-02-29 21:00:00  Saturday
# 2020-02-29 20:00:00  Saturday

# %%
df.loc["2020-01-01"]["High"].count()
# Out:
# 24

# %%
df.loc["2020-01-01"]["High"].max()
# Out:
# 132.68

# %%
df["High"].resample("D")
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
highs = df["High"].resample("D").max()

# %%
highs["2020-01-01"]
# Out:
# 132.68

# %%
df.head(2)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday

# %%
# df[["High", "Low", "Close"]].resample("D").agg(["max", "min", "mean"])

# %%
df.resample("W").mean().head(4)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06

# %%
df.resample("W").agg({'Close' : 'mean', 'High' : 'max', 'Low' : 'min', 'Volume' : 'sum'}).head(10)df
# Out:
#   File "<ipython-input-65-dc9288f60c29>", line 1
#     df.resample("W").agg({'Close' : 'mean', 'High' : 'max', 'Low' : 'min', 'Volume' : 'sum'}).head(10)df
#                                                                                                        ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
df.head(2)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday

# %%
df.resample("D").agg({"High" : "max", "Low" : "min", "Close" : "mean", "Volume" : "sum"}).head(5)
# Out:
#               High     Low       Close       Volume
# Date
# 2017-07-01  279.99  253.23  265.284615  28584024.81
# 2017-07-02  293.73  255.70  269.782500  52262287.78
# 2017-07-03  285.00  273.07  278.882083  35016353.53
# 2017-07-04  282.83  265.00  276.743333  30109905.28
# 2017-07-05  274.97  252.67  265.025833  43150162.52
