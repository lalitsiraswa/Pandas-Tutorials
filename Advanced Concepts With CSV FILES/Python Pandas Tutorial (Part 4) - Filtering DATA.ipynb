# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col = "Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col = "Column")
pd.set_option("display.max_columns", 60)
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
high_salary = (df["ConvertedComp"] > 70000)
print(type(high_salary), "\n")
# print(df[high_salary], "\n")
df.loc[high_salary]
# Out:
# <class 'pandas.core.series.Series'>
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# 24                             I am a developer by profession      Yes  45.0
# 26                             I am a developer by profession       No   NaN
# 36          I am not primarily a developer, but I write co...      Yes  34.0
# 38                             I am a developer by profession       No  35.0
# 41                             I am a developer by profession       No   NaN
# ...

# %%
# df.loc[high_salary, ["Country", "ConvertedComp", "LanguageWorkedWith"]]
df.loc[high_salary][["Country", "ConvertedComp", "LanguageWorkedWith"]].head(2)
# Out:
#                    Country  ConvertedComp  \
# Respondent
# 8            United States       116000.0
# 16          United Kingdom       108576.0
#
#                                            LanguageWorkedWith
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...

# %%
x = df.loc[high_salary][["Country", "ConvertedComp", "LanguageWorkedWith"]]
countries = ["United Kingdom", "United States", "India", "Germany", "Canada"]
filter_Countries = df["Country"].isin(countries)
# df[filter_Countries]["Country"]
df.loc[filter_Countries, "Country"].head(4)
# Out:
# Respondent
# 1           Germany
# 2    United Kingdom
# 5     United States
# 6           Germany
# Name: Country, dtype: object

# %%
df.loc[high_salary][filter_Countries]
# Out:
# C:\Users\DeViL-AnGeL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# 24                             I am a developer by profession      Yes  45.0
# 26                             I am a developer by profession       No   NaN
# 36          I am not primarily a developer, but I write co...      Yes  34.0
# ...

# %%
python_filt = df["LanguageWorkedWith"].str.contains("Python", na = False)
df.loc[python_filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 3                                 I code primarily as a hobby      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# 17                             I am a developer by profession      Yes  25.0
# 22                             I am a developer by profession      Yes   NaN
# 26                             I am a developer by profession       No   NaN
# 27          I used to be a developer by profession, but no...      Yes   NaN
# 28                     I am a student who is learning to code      Yes   NaN
# 29                     I am a student who is learning to code      Yes  18.0
# ...

# %%
countries = ["Germany", "United Kingdom", "India", "Netherlands", "Canada"]
country_filter = df["Country"].isin(countries)

# %%
df.loc[country_filter]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 16                             I am a developer by profession      Yes  45.0
# 22                             I am a developer by profession      Yes   NaN
# 23                             I am a developer by profession      Yes  27.0
# 24                             I am a developer by profession      Yes  45.0
# ...

# %%
countries = ["Poland", "China", "India", "Tunisia", "France", "Nepal"]

# %%
country_filter = df["Country"].isin(countries)

# %%
df[country_filter]["Country"].head(2)
# Out:
# Respondent
# 7      India
# 9    Tunisia
# Name: Country, dtype: object

# %%
df.loc[country_filter, "Country"].tail(2)
# Out:
# Respondent
# 64236     India
# 64925    Poland
# Name: Country, dtype: object

# %%
python_filt = df["LanguageWorkedWith"].str.contains("Python", na = False)
df.loc[python_filt, "LanguageWorkedWith"].head()
# Out:
# Respondent
# 3                             Objective-C;Python;Swift
# 8                                           Python;SQL
# 10                 HTML/CSS;Java;JavaScript;Python;SQL
# 13                                 C;JavaScript;Python
# 15    Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# Name: LanguageWorkedWith, dtype: object
