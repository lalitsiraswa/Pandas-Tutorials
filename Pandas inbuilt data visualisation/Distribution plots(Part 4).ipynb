# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df1 = sns.load_dataset("tips")

# %%
df2 = pd.read_csv("data/ece.csv")

# %%
df110 = df1.head(10)

# %%
df110.plot.hist()

# %%
df110
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df110.plot.hist(bins = 25)

# %%
df110["size"].plot.hist()

# %%
df110.plot.bar()

# %%
df110.loc[7]
# Out:
# total_bill     26.88
# tip             3.12
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 7, dtype: object

# %%
df1.plot.bar()

# %%
df1.plot.area(x = "total_bill", y = "size")

# %%
df110[["size", "tip", "total_bill"]].plot.area(alpha = 0.30)

# %%
# x = np.random.randn(5, 5)
# x

# %%
df110.plot(kind = "hist")

# %%
df110.plot(kind = "bar")

# %%
df110.plot(kind = "line")

# %%
df110.plot(kind = "kde")

# %%
df110.plot.box()

# %%
df110
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df1.plot.box()

# %%
df110["size"].plot.box()

# %%
df110["total_bill"].plot.box()

# %%
df1.plot.hexbin(x = "total_bill", y = "size")

# %%
df110.plot.hexbin(x = "size", y = "total_bill")

# %%
df110
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df110.plot.hexbin(x = "total_bill", y = "tip")

# %%
df110.plot.hexbin(x = "total_bill", y = "tip", gridsize = 25)

# %%
df110.plot.hexbin(x = "size", y = "total_bill", gridsize = 15, cmap = "red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8cba5dae40d0> in <module>
# ----> 1 df110.plot.hexbin(x = "size", y = "total_bill", gridsize = 15, cmap = "red")
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwds)
#    3548         if gridsize is not None:
#    3549             kwds['gridsize'] = gridsize
# -> 3550         return self(kind='hexbin', x=x, y=y, C=C, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
df110.plot.hexbin(x = "size", y = "total_bill", gridsize = 15, cmap = "Set2")

# %%
df110.plot.hexbin(x = "size", y = "total_bill", gridsize = 15)

# %%
df1.plot.hexbin(x = "total_bill", y = "tip", gridsize = 10)
