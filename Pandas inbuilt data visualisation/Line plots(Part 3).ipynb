# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df1 = sns.load_dataset("tips")
df1.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df1.plot.line(x = "size", y = "tip")

# %%
df110 = df1.head(10)
df110.plot.line(x = "size", y = "tip")

# %%
df110
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df110.plot.line()

# %%
df1.plot.line()

# %%
df110["size"].plot.line()

# %%
df110["size"]
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    4
# 5    4
# 6    2
# 7    4
# 8    2
# 9    2
# Name: size, dtype: int64

# %%
df110["tip"].plot.line()

# %%
df110["tip"]
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# 5    4.71
# 6    2.00
# 7    3.12
# 8    1.96
# 9    3.23
# Name: tip, dtype: float64

# %%
df110.plot.line()

# %%
df110["total_bill"]
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# 5    25.29
# 6     8.77
# 7    26.88
# 8    15.04
# 9    14.78
# Name: total_bill, dtype: float64

# %%
df110["size"].plot.kde()

# %%
df110["size"]
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    4
# 5    4
# 6    2
# 7    4
# 8    2
# 9    2
# Name: size, dtype: int64

# %%
df110["size"].plot.density()
